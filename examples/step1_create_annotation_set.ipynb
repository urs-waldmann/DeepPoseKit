# %% [markdown]
# <a href="https://colab.research.google.com/github/jgraving/deepposekit/blob/master/examples/step1_create_annotation_set.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DeepPoseKit Step 1 - Create an annotation set
#
# This is step 1 of the example notebooks for using DeepPoseKit. This notebook shows you how to load and sample images from a video, define a keypoint skeleton, and save the data to a file for labelling with keypoints.
#
#
# **NOTE**: If you run into problems, you can help us improve DeepPoseKit by [opening an issue](https://github.com/jgraving/deepposekit/issues/new) or [submitting a pull request](https://help.github.com/en/articles/creating-a-pull-request-from-a-fork)

# %% [markdown]
# If you haven't already installed DeepPoseKit you can run the next cell

# %%
import sys
# !{sys.executable} -m pip install -U deepposekit

# %%
import numpy as np
import cv2
import h5py
import matplotlib.pyplot as plt
from deepposekit.io import VideoReader, DataGenerator, initialize_dataset
from deepposekit.annotate import KMeansSampler
import tqdm
import glob
import pandas as pd

from os.path import expanduser

try:
    import google.colab
    IN_COLAB = True
except:
    IN_COLAB = False

HOME = expanduser("~") if not IN_COLAB else '.'

# %% [markdown]
# # A note on image resolutions
#
# Currently DeepPoseKit only supports image resolutions that can be repeatedly divided by 2. For example, all of these values are valid image resolutions for either height or width:

# %%
exp = np.arange(1,12)
exp = 2**exp

print(1*exp)
print(3*exp)
print(5*exp)
print(7*exp)
print(11*exp)
# Out:
# [   2    4    8   16   32   64  128  256  512 1024 2048]
# [   6   12   24   48   96  192  384  768 1536 3072 6144]
# [   10    20    40    80   160   320   640  1280  2560  5120 10240]
# [   14    28    56   112   224   448   896  1792  3584  7168 14336]
# [   22    44    88   176   352   704  1408  2816  5632 11264 22528]

# %% [markdown]
# Images that do not match these resolutions must be manually resized, cropped, or padded. We are working to add automated image size adjustments.

# %% [markdown]
# # Open a video
# The `VideoReader` class allows you to load in single video frames or batches of frames from nearly any video format.

# %%
videos = glob.glob(HOME + '/Videos/*.mp4')
videos
# Out:
# ['/home/urs/Videos/spider.mp4']

# %%
reader = VideoReader(HOME + '/Videos/spider.mp4', gray=False)
frame = reader[0] # read a frame
reader.close()
frame.shape
# Out:
# (1, 480, 640, 3)

# %%
plt.figure(figsize=(5,5))
plt.imshow(frame[0,...,0])
plt.show()

# %% [markdown]
# # Sample video frames
# This loads batches of 100 frames from the video, and then randomly samples frames from the batches to hold them in memory. You can use any method for sampling frames.

# %%
reader = VideoReader(HOME + '/Videos/spider.mp4', batch_size=100, gray=False)

randomly_sampled_frames = []
for idx in tqdm.tqdm(range(len(reader)-1)):
    batch = reader[idx]
    random_sample = batch[np.random.choice(batch.shape[0], 10, replace=False)]
    randomly_sampled_frames.append(random_sample)
reader.close()

randomly_sampled_frames = np.concatenate(randomly_sampled_frames)
randomly_sampled_frames.shape
# Out:
# 100%|██████████| 4/4 [00:00<00:00,  8.50it/s]
# (40, 480, 640, 3)

# %% [markdown]
# # Apply k-means to reduce correlation
#
# This applies the k-means algorithm to the images using `KMeansSampler` to even out sampling across the distribution of images and reduce correlation within the annotation set.

# %%
kmeans = KMeansSampler(n_clusters=10, max_iter=1000, n_init=10, batch_size=100, verbose=True)
kmeans.fit(randomly_sampled_frames)
# Out:
# Init 1/10 with method: k-means++
# Inertia for init 1/10: 1056116591.227169
# Init 2/10 with method: k-means++
# Inertia for init 2/10: 1031111993.762897
# Init 3/10 with method: k-means++
# Inertia for init 3/10: 1075465165.108540
# Init 4/10 with method: k-means++
# Inertia for init 4/10: 978791766.559246
# Init 5/10 with method: k-means++
# Inertia for init 5/10: 1033933074.352940
# Init 6/10 with method: k-means++
# Inertia for init 6/10: 1081310243.837746
# Init 7/10 with method: k-means++
# Inertia for init 7/10: 906244313.128967
# Init 8/10 with method: k-means++
# Inertia for init 8/10: 1063316179.323505
# Init 9/10 with method: k-means++
# Inertia for init 9/10: 1032107563.789585
# Init 10/10 with method: k-means++
# Inertia for init 10/10: 1051488117.803043
# Minibatch iteration 1/1000: mean batch inertia: 40403282.969113, ewa inertia: 40403282.969113
# Minibatch iteration 2/1000: mean batch inertia: 36853014.298195, ewa inertia: 36853014.298195
# Minibatch iteration 3/1000: mean batch inertia: 33895400.470283, ewa inertia: 33895400.470283
# Minibatch iteration 4/1000: mean batch inertia: 32149215.728184, ewa inertia: 32149215.728184
# Minibatch iteration 5/1000: mean batch inertia: 35511578.918557, ewa inertia: 35511578.918557
# Minibatch iteration 6/1000: mean batch inertia: 32499984.548310, ewa inertia: 32499984.548310
# Minibatch iteration 7/1000: mean batch inertia: 33095873.112930, ewa inertia: 33095873.112930
# Minibatch iteration 8/1000: mean batch inertia: 34166460.994881, ewa inertia: 34166460.994881
# Minibatch iteration 9/1000: mean batch inertia: 31409666.998368, ewa inertia: 31409666.998368
# Minibatch iteration 10/1000: mean batch inertia: 34096414.420574, ewa inertia: 34096414.420574
# Minibatch iteration 11/1000: mean batch inertia: 35306329.367462, ewa inertia: 35306329.367462
# Minibatch iteration 12/1000: mean batch inertia: 34645148.858479, ewa inertia: 34645148.858479
# Minibatch iteration 13/1000: mean batch inertia: 32284894.027009, ewa inertia: 32284894.027009
# Minibatch iteration 14/1000: mean batch inertia: 31964360.533846, ewa inertia: 31964360.533846
# Minibatch iteration 15/1000: mean batch inertia: 36048778.293485, ewa inertia: 36048778.293485
# Minibatch iteration 16/1000: mean batch inertia: 33286044.004339, ewa inertia: 33286044.004339
# Minibatch iteration 17/1000: mean batch inertia: 32030473.925026, ewa inertia: 32030473.925026
# Minibatch iteration 18/1000: mean batch inertia: 35789886.123060, ewa inertia: 35789886.123060
# Minibatch iteration 19/1000: mean batch inertia: 31366403.472741, ewa inertia: 31366403.472741
# Minibatch iteration 20/1000: mean batch inertia: 31429264.421430, ewa inertia: 31429264.421430
# Minibatch iteration 21/1000: mean batch inertia: 31002771.550341, ewa inertia: 31002771.550341
# Minibatch iteration 22/1000: mean batch inertia: 32533336.536525, ewa inertia: 32533336.536525
# Minibatch iteration 23/1000: mean batch inertia: 29053489.881696, ewa inertia: 29053489.881696
# Minibatch iteration 24/1000: mean batch inertia: 32579396.296988, ewa inertia: 32579396.296988
# Minibatch iteration 25/1000: mean batch inertia: 33416749.857878, ewa inertia: 33416749.857878
# Minibatch iteration 26/1000: mean batch inertia: 32634539.142210, ewa inertia: 32634539.142210
# Minibatch iteration 27/1000: mean batch inertia: 32467767.892369, ewa inertia: 32467767.892369
# Minibatch iteration 28/1000: mean batch inertia: 32396517.698772, ewa inertia: 32396517.698772
# Minibatch iteration 29/1000: mean batch inertia: 33518812.609000, ewa inertia: 33518812.609000
# Minibatch iteration 30/1000: mean batch inertia: 32337954.322323, ewa inertia: 32337954.322323
# Minibatch iteration 31/1000: mean batch inertia: 32670620.673801, ewa inertia: 32670620.673801
# Minibatch iteration 32/1000: mean batch inertia: 30876128.206827, ewa inertia: 30876128.206827
# Minibatch iteration 33/1000: mean batch inertia: 33131980.605263, ewa inertia: 33131980.605263
# Converged (lack of improvement in inertia) at iteration 33/1000
# Computing label assignment and total inertia
# KMeansSampler(batch_size=100, compute_labels=True, init='k-means++',
#               init_size=None, max_iter=1000, max_no_improvement=10,
#               n_clusters=10, n_init=10, random_state=None,
#               reassignment_ratio=0.01, tol=0.0, verbose=True)

# %%
kmeans.plot_centers(n_rows=2)
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
kmeans_sampled_frames, kmeans_cluster_labels = kmeans.sample_data(randomly_sampled_frames, n_samples_per_label=10)
kmeans_sampled_frames.shape
# Out:
# Computing label assignment and total inertia
# Computing label assignment and total inertia
# (40, 480, 640, 3)

# %% [markdown]
# # Define a keypoints skeleton file
# You must create a .xlsx or .csv file with keypoint names, parent relationships, and swapping relationships for bilaterally symmetric parts (only relevant if using flipping augmentations). If you leave out the `parent` and `swap` columns, then these will simply not be used for annotating data and training the model.
#
# See example skeleton.csv files for more details

# %%
skeleton = pd.read_csv(HOME + '/Documents/programming/my_data_spider/skeleton.csv')
skeleton
# Out:
#            name    parent   swap
# 0          head       NaN    NaN
# 1      body_top      head    NaN
# 2   body_bottom  body_top    NaN
# 3         legR1      head  legL1
# 4         legR2      head  legL2
# 5         legR3      head  legL3
# 6         legR4      head  legL4
# 7         legL1      head  legR1
# 8         legL2      head  legR2
# 9         legL3      head  legR3
# 10        legL4      head  legR4

# %% [markdown]
# # Initialize a new data set for annotations
#
# You can use any method for sampling images to create a numpy array with the shape (n_images, height, width, channels) and then initialize an annotation set. Check the doc string for more details:

# %%
initialize_dataset?
# Out:
# Signature:
# initialize_dataset(
#     datapath,
#     images,
#     skeleton,
#     keypoints=None,
#     dataset='images',
#     overwrite=False,
# )
# Docstring:
# Intialize an image dataset for annotation as an h5 file
#
# Parameters
# ----------
# datapath : str
#     The path to the annotations file. Must be .h5
#     e.g. '/path/to/file.h5'
# images : ndarray, shape (n_images, height, width, channels)
#     A numpy array containing image data.
#     `images.dtype` should be np.uint8
# skeleton: str or pandas.DataFrame
#     Filepath of the .csv or .xlsx file that has indexed information
#     on name of the keypoint (part, e.g. head), parent (the direct
#     connecting part, e.g. neck connects to head, parent is head),
#     and swap (swapping positions with a part when reflected).
#     See example files for more information.
# keypoints : None or ndarray, shape (n_images, n_keypoints, 2)
#     Optionally pass keypoints for initializing annotations for the
#     new images.
# dataset : str, default = "images"
#     The name of the dataset within the h5 file to save the images.
# overwrite: bool, default = False
#     Whether to overwrite an existing .h5 file with the same name.
# File:      ~/anaconda3/envs/DeepPoseKit/lib/python3.7/site-packages/deepposekit/io/utils.py
# Type:      function

# %%
initialize_dataset(
    images=kmeans_sampled_frames,
    datapath=HOME + '/Documents/programming/my_data_spider/spider_annotation_set.h5',
    skeleton=HOME + '/Documents/programming/my_data_spider/skeleton.csv',
    # overwrite=True # This overwrites the existing datapath
)

# %% [markdown]
# # Create a data generator
# This creates a `DataGenerator` for loading annotated data. Indexing the generator returns an image-keypoints pair, which you can then visualize. Right now all the keypoints are set to zero, because they haven't been annotated.
#
# You can also look at the doc string for more explanation:

# %%
DataGenerator?

# %%
data_generator = DataGenerator(HOME + '/deepposekit-data/datasets/fly/example_annotation_set.h5', mode="full")

image, keypoints = data_generator[0]

plt.figure(figsize=(5,5))
image = image[0] if image.shape[-1] is 3 else image[0, ..., 0]
cmap = None if image.shape[-1] is 3 else 'gray'
plt.imshow(image, cmap=cmap, interpolation='none')
for idx, jdx in enumerate(data_generator.graph):
    if jdx > -1:
        plt.plot(
            [keypoints[0, idx, 0], keypoints[0, jdx, 0]],
            [keypoints[0, idx, 1], keypoints[0, jdx, 1]],
            'r-'
        )
plt.scatter(keypoints[0, :, 0], keypoints[0, :, 1], c=np.arange(data_generator.keypoints_shape[0]), s=50, cmap=plt.cm.hsv, zorder=3)

plt.show()
